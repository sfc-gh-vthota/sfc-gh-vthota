# %% [markdown]
# # 🏦 JPMC Consumer Banking - Hands-on Lab
# ## Notebook 09: Cleanup - Remove All HOL Objects
#
# ---
#
# ### ⚠️ WARNING: This notebook drops ALL objects created during the HOL.
#
# Run this only when the lab is complete and you want to clean up your account.
#
# **Objects removed:**
# - All Tasks (suspended first, then dropped)
# - All Dynamic Tables
# - All Pipes
# - All Tables (native + Iceberg)
# - Compute Pool
# - Stages and File Formats
# - Alerts
# - Stored Procedures
# - Schemas and Database
# - Warehouses

# %%
-- =============================================================================
-- HOL CLEANUP SCRIPT
-- Run as ACCOUNTADMIN
-- =============================================================================

USE ROLE ACCOUNTADMIN;

# %% [markdown]
# ## Step 1: Suspend and Drop All Tasks

# %%
-- Suspend root tasks first (children auto-suspend)
ALTER TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_ROOT SUSPEND;
ALTER TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_NB_PIPELINE_ROOT SUSPEND;

-- Drop all tasks (children first, then root)
DROP TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_EXEC_DASHBOARD;
DROP TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_CUSTOMER_360;
DROP TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_TXN_SUMMARY;
DROP TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_ROOT;

DROP TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_NB_04C_ACTIVITY_SNAPSHOT;
DROP TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_NB_04B_LATE_PAYMENTS;
DROP TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_NB_04A_STATEMENTS;
DROP TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_NB_PIPELINE_ROOT;

DROP TASK IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TASK_ERROR_MONITOR;

# %% [markdown]
# ## Step 2: Drop Alerts and Pipes

# %%
-- Drop alerts
DROP ALERT IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.HOL_ERROR_THRESHOLD_ALERT;

-- Drop pipes
DROP PIPE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.HOL_TRANSACTIONS_PIPE;

# %% [markdown]
# ## Step 3: Drop Dynamic Tables

# %%
-- Drop Dynamic Tables (downstream first)
DROP DYNAMIC TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.EXECUTIVE_DASHBOARD;
DROP DYNAMIC TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.CUSTOMER_360;
DROP DYNAMIC TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TXN_SUMMARY;

# %% [markdown]
# ## Step 4: Drop Stored Procedures

# %%
-- Drop stored procedures
DROP PROCEDURE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.SP_REFRESH_CUSTOMER_360();
DROP PROCEDURE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.SP_REFRESH_TXN_SUMMARY();
DROP PROCEDURE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.SP_REFRESH_EXECUTIVE_DASHBOARD();

# %% [markdown]
# ## Step 5: Drop All Tables (Native + Iceberg + SP output)

# %%
-- Native tables
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.CUSTOMERS;
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TRANSACTIONS;
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.SUPPORT_TICKETS;

-- Iceberg tables
DROP ICEBERG TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.ACCOUNTS;
DROP ICEBERG TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.LOANS;
DROP ICEBERG TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.CREDIT_CARDS;
DROP ICEBERG TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.SPARK_CUSTOMER_PORTFOLIO;

-- SP output tables
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.CUSTOMER_360_SP;
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TXN_SUMMARY_SP;
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.EXECUTIVE_DASHBOARD_SP;

-- Notebook output tables
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.MONTHLY_STATEMENTS;
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.LATE_PAYMENT_FLAGS;
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.CUSTOMER_ACTIVITY_SNAPSHOT;

-- Cortex AI output
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.SUPPORT_TICKETS_AI_ENRICHED;

-- Observability tables
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TRANSACTIONS_VALIDATED;
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TRANSACTIONS_STREAMING_PIPE;
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.TRANSACTIONS_REALTIME;
DROP TABLE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.ERROR_ALERT_LOG;

# %% [markdown]
# ## Step 6: Drop Integrations, Policies, Stages, File Formats

# %%
-- Drop catalog integration
DROP CATALOG INTEGRATION IF EXISTS HOL_ICEBERG_CATALOG;

-- Drop notification integration
DROP NOTIFICATION INTEGRATION IF EXISTS HOL_SNOWPIPE_NOTIFICATION;

-- Drop storage lifecycle policy
DROP STORAGE LIFECYCLE POLICY IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.HOL_TXN_ARCHIVE_POLICY;

-- Drop stages
DROP STAGE IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.HOL_PARQUET_STAGE;

-- Drop file formats
DROP FILE FORMAT IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.HOL_PARQUET_FF;
DROP FILE FORMAT IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB.HOL_CSV_FF;

# %% [markdown]
# ## Step 7: Drop Compute Pool, Schemas, Database, and Warehouses

# %%
-- Drop compute pool
DROP COMPUTE POOL IF EXISTS HOL_SPARK_POOL;

-- Drop schemas (CASCADE drops any remaining objects)
DROP SCHEMA IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_STAGING CASCADE;
DROP SCHEMA IF EXISTS JPMC_CONSUMER_BANKING_HOL.HOL_LAB CASCADE;

-- Drop database
DROP DATABASE IF EXISTS JPMC_CONSUMER_BANKING_HOL;

-- Drop warehouses
DROP WAREHOUSE IF EXISTS HOL_XS_WH;
DROP WAREHOUSE IF EXISTS HOL_MEDIUM_WH;
DROP WAREHOUSE IF EXISTS HOL_SNOWPARK_OPT_WH;

# %% [markdown]
# ## ✅ Cleanup Complete
#
# All HOL objects have been removed. Your account is back to its pre-lab state.
#
# | Dropped | Objects |
# |---------|---------|
# | Database | JPMC_CONSUMER_BANKING_HOL (+ all schemas) |
# | Warehouses | HOL_XS_WH, HOL_MEDIUM_WH, HOL_SNOWPARK_OPT_WH |
# | Compute Pool | HOL_SPARK_POOL |
# | Integrations | HOL_ICEBERG_CATALOG, HOL_SNOWPIPE_NOTIFICATION |
# | Tasks | All TASK_* objects |
# | Dynamic Tables | CUSTOMER_360, TXN_SUMMARY, EXECUTIVE_DASHBOARD |
# | Tables | All native + Iceberg + output tables |
# | Procedures | All SP_REFRESH_* procedures |
